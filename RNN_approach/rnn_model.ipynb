# %%
import numpy as np 
import pandas as pd

# %%
# data pre-processing
df_train = pd.read_csv(r"..\Data\Train_and_Test_dataset\train.csv")
df_train
# Out:
#                                                    title  \
# 0                                                   Code
# 1                                                   Axel
# 2                                    Measuring the World
# 3                                      Les Belles-Soeurs
# 4                            Autonauts of the Cosmoroute
# ...                                                  ...
# 37576                                The Act of Creation
# 37577                                        Cowboy Heat
# 37578                                                NaN
# 37579                        The Murder of Roger Ackroyd
# 37580  Wired: The Short Life and Fast Times of John B...
#
#                                                   author  \
# 0      Kathy Reichs (Goodreads Author), Brendan Reich...
# 1                        Harper Sloan (Goodreads Author)
# 2      Daniel Kehlmann, Carol Brown Janeway (Translator)
# ...

# %%
df_train = pd.read_pickle("..\Data\Train_and_Test_dataset\X_train.pkl")
df_train

# %%
print(df_train.iloc[0])
# Out:
# [ 0.03260905 -0.09344769 -0.07144769  0.07523922  0.03258742  0.00520314
#   0.04216785  0.13672632 -0.03219291 -0.05447785  0.02471639  0.04591793
#  -0.096175    0.05821119  0.01475904 -0.0195677   0.02883205  0.03326984
#   0.02910036  0.01499561  0.05090975 -0.03291731 -0.04772814  0.02211757
#   0.01606234 -0.01190706  0.02577727 -0.09015816  0.02078798 -0.02344835
#   0.0421352   0.02004905  0.07010467 -0.04080433 -0.00344079  0.0420731
#   0.01313551  0.00905455 -0.00642226 -0.09338189  0.02050971 -0.07305072
#   0.06844209  0.00528498  0.06368373  0.000686   -0.11680833 -0.04439683
#   0.07405743 -0.0374609  -0.05701125 -0.03022136  0.02585765 -0.00412186
#  -0.03707781 -0.03095935  0.02898791 -0.02905446  0.02650332  0.00997825
#   0.07520578  0.0415978   0.08605457 -0.04551845 -0.12479863  0.03792108
#  -0.03430622  0.05373131 -0.01183065 -0.02578399  0.05823385  0.01841547
#   0.00433695  0.0489811   0.12784643 -0.00668045  0.0046016   0.03472709
# ...
